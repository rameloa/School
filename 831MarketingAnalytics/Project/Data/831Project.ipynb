# %% [markdown]
# Team Gordon
#
# Student Name	Student Number
#  Alisha Sahota	20497348
#  Anthony Ramelo	20499391
#  Chris Wu	10182394
#  Elizabeth Zhang	20161231
#  Emily Zhao	10096273
#  Sam Hossain	20466500

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.impute import KNNImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.model_selection import train_test_split
from scipy.stats import skew

# Load Data
dfcrosssection = pd.read_excel('Data 3 - October, 2024.xlsx', sheet_name='Parachute - Cross Section')
dfcrosssection['ID'] = dfcrosssection['ID'].astype(str)
dftupanel = pd.read_excel('Data 3 - October, 2024.xlsx', sheet_name='TU - Panel')
dfmonthlywellness = pd.read_excel('Data 3 - October, 2024.xlsx', sheet_name='Monthly Wellness and Engagement')
dfmonthlywellness['loanid'] = dfmonthlywellness['loanid'].astype(str)
dfGoals_and_plans_ALLDATA_202410 = pd.read_excel('Data 3 - October, 2024.xlsx', sheet_name='Goals_and_plans_ALLDATA_202410')
dfGoals_and_plans_ALLDATA_202410['public_id'] = '1' + dfGoals_and_plans_ALLDATA_202410['public_id'].astype(str)
dfAddiitonalTUData = pd.read_excel('Data 3 - October, 2024.xlsx', sheet_name='Addiitonal TU Data')

# Merge Data
merged_data = dfGoals_and_plans_ALLDATA_202410.merge(dfmonthlywellness, how='left', left_on='public_id', right_on='loanid')
merged_data = merged_data.merge(dfcrosssection, how='left', left_on='public_id', right_on='ID')

# Drop Columns
merged_data = merged_data.drop(columns=['id', 'assessment_month', 'admin_notes', 'id-date', 'ID'])

# Drop Duplicates and Nulls
distinct_rows = merged_data.drop_duplicates().dropna(subset=['Loan Status'])

# Convert date columns to datetime
date_columns = ['assessment_completed_date', 'month_being_assessed', 'plan_date1', 'Disbursement Date', 'Date of Birth']
for col in date_columns:
    distinct_rows[col] = pd.to_datetime(distinct_rows[col], errors='coerce')

# Drop columns with more than 80% missing values
missing_values = distinct_rows.isnull().mean() * 100
columns_to_drop = missing_values[missing_values > 80].index
df_cleaned = distinct_rows.drop(columns=columns_to_drop)

# Step 1: Split Data
train_data, test_data = train_test_split(df_cleaned, test_size=0.2, random_state=42)

# Step 2: Imputation on Training Data Only
numeric_cols = train_data.select_dtypes(include=[np.number]).columns

# KNN Imputation
knn_imputer = KNNImputer(n_neighbors=5)
train_knn_imputed = train_data.copy()
train_knn_imputed[numeric_cols] = knn_imputer.fit_transform(train_knn_imputed[numeric_cols])

# Impute test set based on training fit
test_knn_imputed = test_data.copy()
test_knn_imputed[numeric_cols] = knn_imputer.transform(test_knn_imputed[numeric_cols])

# MICE Imputation
mice_imputer = IterativeImputer(max_iter=10, random_state=0)
train_mice_imputed = train_data.copy()
train_mice_imputed[numeric_cols] = mice_imputer.fit_transform(train_mice_imputed[numeric_cols])

# Impute test set based on training fit
test_mice_imputed = test_data.copy()
test_mice_imputed[numeric_cols] = mice_imputer.transform(test_mice_imputed[numeric_cols])

# Conditional Median Imputation based on 'Province'
train_conditional_imputed = train_data.copy()
for col in numeric_cols:
    train_conditional_imputed[col] = train_conditional_imputed.groupby('Province')[col].transform(
        lambda x: x.fillna(x.median())
    )

test_conditional_imputed = test_data.copy()
for col in numeric_cols:
    test_conditional_imputed[col] = test_conditional_imputed.groupby('Province')[col].transform(
        lambda x: x.fillna(x.median())
    )

# Step 3: Variance Comparison Across Imputed Datasets for Training Data Only
comparison_df = pd.DataFrame({
    "Original": train_data[numeric_cols].var(),
    "KNN Imputed": train_knn_imputed[numeric_cols].var(),
    "MICE Imputed": train_mice_imputed[numeric_cols].var(),
    "Conditional Median Imputed": train_conditional_imputed[numeric_cols].var()
})

print(comparison_df)

# Step 4: Calculate and Plot Skewness for KNN-Imputed Training Data
knn_skewness = pd.Series(
    {col: skew(train_knn_imputed[col].dropna()) for col in numeric_cols},
    name="KNN Skewness"
)

print(knn_skewness)

# Plot skewness of each numeric column in KNN-imputed dataset
plt.figure(figsize=(12, 8))
knn_skewness.sort_values().plot(kind='barh', color='skyblue', edgecolor='black')
plt.title('Skewness of Each Numeric Column in KNN-Imputed Training Dataset')
plt.xlabel('Skewness')
plt.ylabel('Columns')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()
# Out:
#                                         Original   KNN Imputed  MICE Imputed  \
# goal_paid_parachute_on_time         1.163748e-01  1.162414e-01  1.161938e-01
# user_id                             2.824611e+13  2.824611e+13  2.824611e+13
# count_apply_savings_to_cc           2.875254e+00  2.875254e+00  2.875254e+00
# count_auto_withdrawal               8.187311e-02  8.187311e-02  8.187311e-02
# count_chat_before_new_debt          1.078896e-01  1.078896e-01  1.078896e-01
# count_chat_for_debt_reduction       7.347666e-02  7.347666e-02  7.347666e-02
# count_contact_biller                2.243531e-01  2.243531e-01  2.243531e-01
# count_no_new_debt_upcoming_month    8.564367e-01  8.564367e-01  8.564367e-01
# count_pay_more_on_cc                5.098957e+00  5.098957e+00  5.098957e+00
# count_pay_of_cc                     1.462854e-01  1.462854e-01  1.462854e-01
# count_spend_less                    1.753747e-01  1.753747e-01  1.753747e-01
# count_custom1                       9.260534e-02  9.260534e-02  9.260534e-02
# count_custom2                       2.193729e-01  2.193729e-01  2.193729e-01
# count_custom3                       9.896712e-02  9.896712e-02  9.896712e-02
# quiz_answer_count                   8.349494e+00  8.345680e+00  8.343123e+00
# mood_answer_count                   4.898290e+00  4.895941e+00  4.894552e+00
# inspiration_answer_count            2.053304e+00  2.052054e+00  2.051738e+00
# self_assessment_count               3.384186e-01  3.381704e-01  3.381604e-01
# activities_count                    2.605387e+01  2.604414e+01  2.603399e+01
# wellness_score                      1.667104e+02  1.620965e+02  1.569874e+02
# Loan Amount                         3.022975e+07  3.022975e+07  3.022975e+07
# Outstanding Balance                 8.701289e+07  8.701289e+07  8.701289e+07
# Outstanding Principal               3.195833e+07  3.195833e+07  3.195833e+07
# Interest Rate                       2.890718e-04  2.890718e-04  2.890718e-04
# Loan Term (Months)                  5.343320e+01  5.343320e+01  5.343320e+01
# Stated Income on application        7.933062e+08  7.933062e+08  7.933062e+08
# Qualified / Verified\nIncome        3.389828e+09  3.389828e+09  3.389828e+09
# Aptitude for change Score           1.065929e+00  1.094182e+00  1.070252e+00
# Financial Literacy Score            3.274009e+00  3.251191e+00  3.577652e+00
# Self Assessments                    3.527746e+01  3.595449e+01  3.027583e+01
# Quiz Count                          2.956390e+03  3.029084e+03  2.537233e+03
# Mood Count                          9.761141e+02  9.791953e+02  8.377206e+02
# Inspiration Count                   3.215448e+02  3.157648e+02  2.759562e+02
# Total Activies                      9.238917e+03  9.306874e+03  7.929024e+03
# Average total activities per month  1.072884e+01  1.137368e+01  9.207709e+00
# Average activities per day          1.192047e-02  1.263723e-02  1.023039e-02
#
#                                     Conditional Median Imputed
# goal_paid_parachute_on_time                       1.162204e-01
# user_id                                           2.824611e+13
# count_apply_savings_to_cc                         2.875254e+00
# count_auto_withdrawal                             8.187311e-02
# count_chat_before_new_debt                        1.078896e-01
# count_chat_for_debt_reduction                     7.347666e-02
# count_contact_biller                              2.243531e-01
# count_no_new_debt_upcoming_month                  8.564367e-01
# count_pay_more_on_cc                              5.098957e+00
# count_pay_of_cc                                   1.462854e-01
# count_spend_less                                  1.753747e-01
# count_custom1                                     9.260534e-02
# count_custom2                                     2.193729e-01
# count_custom3                                     9.896712e-02
# quiz_answer_count                                 8.343473e+00
# mood_answer_count                                 4.895654e+00
# inspiration_answer_count                          2.052064e+00
# self_assessment_count                             3.381631e-01
# activities_count                                  2.603424e+01
# wellness_score                                    1.530797e+02
# Loan Amount                                       3.022975e+07
# Outstanding Balance                               8.701289e+07
# Outstanding Principal                             3.195833e+07
# Interest Rate                                     2.890718e-04
# Loan Term (Months)                                5.343320e+01
# Stated Income on application                      7.933062e+08
# Qualified / Verified\nIncome                      3.389828e+09
# Aptitude for change Score                         1.052709e+00
# Financial Literacy Score                          3.235832e+00
# Self Assessments                                  3.110050e+01
# Quiz Count                                        2.610344e+03
# Mood Count                                        8.495702e+02
# Inspiration Count                                 2.787367e+02
# Total Activies                                    8.009482e+03
# Average total activities per month                9.397805e+00
# Average activities per day                        1.044169e-02
# goal_paid_parachute_on_time           -2.143255
# user_id                                1.580588
# count_apply_savings_to_cc              1.696144
# count_auto_withdrawal                  9.281217
# count_chat_before_new_debt             3.154742
# count_chat_for_debt_reduction          8.491474
# count_contact_biller                   5.091207
# count_no_new_debt_upcoming_month       3.618194
# count_pay_more_on_cc                   1.004893
# count_pay_of_cc                        4.477530
# count_spend_less                       6.651782
# count_custom1                          7.327369
# count_custom2                          3.736487
# count_custom3                          6.759478
# quiz_answer_count                     -0.423773
# mood_answer_count                      3.282655
# inspiration_answer_count               3.732332
# self_assessment_count                 15.494944
# activities_count                       1.760153
# wellness_score                         0.024381
# Loan Amount                            0.166241
# Outstanding Balance                   -0.209675
# Outstanding Principal                 -0.279209
# Interest Rate                         -0.950724
# Loan Term (Months)                    -1.244813
# Stated Income on application           6.747311
# Qualified / Verified\nIncome           7.432845
# Aptitude for change Score             -1.287659
# Financial Literacy Score              -0.074862
# Self Assessments                      -0.170407
# Quiz Count                            -0.340124
# Mood Count                             1.469206
# Inspiration Count                      1.462298
# Total Activies                         0.394307
# Average total activities per month    -0.153577
# Average activities per day            -0.153767
# Name: KNN Skewness, dtype: float64

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configure visualization style
# %matplotlib inline
sns.set(style='whitegrid', palette='deep')

# Load Data
df_crosssection = pd.read_excel('Data 3 - October, 2024.xlsx', sheet_name='Parachute - Cross Section')
df_crosssection['ID'] = df_crosssection['ID'].astype(str)

df_tu_panel = pd.read_excel('Data 3 - October, 2024.xlsx', sheet_name='TU - Panel')

df_monthly_wellness = pd.read_excel('Data 3 - October, 2024.xlsx', sheet_name='Monthly Wellness and Engagement')
df_monthly_wellness['loanid'] = df_monthly_wellness['loanid'].astype(str)

df_goals_plans = pd.read_excel('Data 3 - October, 2024.xlsx', sheet_name='Goals_and_plans_ALLDATA_202410')
df_goals_plans['public_id'] = '1' + df_goals_plans['public_id'].astype(str)

df_additional_tu = pd.read_excel('Data 3 - October, 2024.xlsx', sheet_name='Addiitonal TU Data')

# Merge DataFrames
df_merged = df_goals_plans.merge(df_monthly_wellness, how='left', left_on='public_id', right_on='loanid')
df_merged = df_merged.merge(df_crosssection, how='left', left_on='public_id', right_on='ID')

# Drop unnecessary columns
df_merged.drop(columns=['id', 'assessment_month', 'admin_notes', 'id-date', 'ID'], inplace=True)

# Drop duplicates
df_merged.drop_duplicates(inplace=True)

# Convert date columns to datetime
date_cols = ['assessment_completed_date', 'month_being_assessed', 'plan_date1', 'Disbursement Date', 'Date of Birth']
for col in date_cols:
    df_merged[col] = pd.to_datetime(df_merged[col], errors='coerce')

# **Insert: Standardize column names**
# Standardize column names: strip spaces and convert to lowercase
df_merged.columns = df_merged.columns.str.strip().str.lower()

# Data Overview

# Preview the first few rows
print("First few rows of the merged dataset:")
display(df_merged.head())

# Get DataFrame info
print("\nDataFrame Information:")
df_merged.info()

# Summary statistics for numeric variables
print("\nSummary Statistics for Numeric Variables:")
display(df_merged.describe())

# Summary statistics for categorical variables
print("\nSummary Statistics for Categorical Variables:")
display(df_merged.describe(include=['object']))

# Handling Missing Values

# Calculate missing values
missing_values = df_merged.isnull().sum().sort_values(ascending=False)
missing_percent = (df_merged.isnull().sum() / len(df_merged) * 100).sort_values(ascending=False)

# Create a DataFrame for missing values
missing_data = pd.DataFrame({'Total Missing': missing_values, 'Percent Missing': missing_percent})
print("\nMissing Values in the Dataset:")
display(missing_data.head(20))

# Visualize missing data using a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df_merged.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# Drop columns with more than 50% missing values
threshold = 50  # percent
columns_to_drop = missing_data[missing_data['Percent Missing'] > threshold].index
df_merged.drop(columns=columns_to_drop, inplace=True)

print(f"\nDropped columns due to high missing rate (> {threshold}%):")
print(list(columns_to_drop))

# Exploratory Data Analysis

# Identify numeric and categorical columns
numeric_cols = df_merged.select_dtypes(include=[np.number]).columns.tolist()
categorical_cols = df_merged.select_dtypes(include=['object']).columns.tolist()

# Univariate Analysis - Numeric Variables
print("\nPlotting histograms for numeric variables...")
df_merged[numeric_cols].hist(figsize=(16, 12), bins=20, edgecolor='black')
plt.tight_layout()
plt.show()

# Univariate Analysis - Categorical Variables
# Exclude columns with too many unique values
categorical_cols = [col for col in categorical_cols if df_merged[col].nunique() < 20 and col != 'public_id']

print("\nPlotting bar charts for categorical variables...")
for col in categorical_cols:
    plt.figure(figsize=(8, 4))
    sns.countplot(data=df_merged, x=col, order=df_merged[col].value_counts().index)
    plt.xticks(rotation=45)
    plt.title(f'Distribution of {col}')
    plt.show()

# Bivariate Analysis - Correlation Matrix
print("\nCorrelation Matrix of Numeric Variables:")
corr_matrix = df_merged[numeric_cols].corr()

# Plot heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True)
plt.title('Correlation Matrix')
plt.show()

# Bivariate Analysis - Pairplot
# **Update: Adjust subset_cols with standardized column names**
# Select a subset of numeric columns for pairplot
subset_cols = ['wellness_score', 'financial literacy score', 'aptitude for change score', 'loan amount', 'interest rate']

# Verify that all columns in subset_cols exist in df_merged
missing_cols = [col for col in subset_cols if col not in df_merged.columns]
if missing_cols:
    print(f"The following columns are missing in df_merged: {missing_cols}")
else:
    print("All subset columns are present in df_merged.")

# Drop NaNs in these columns
df_pairplot = df_merged[subset_cols].dropna()

print("\nPlotting pairplot for selected variables...")
sns.pairplot(df_pairplot)
plt.show()

# Bivariate Analysis - Relationship with Target Variable
# **Update: Use standardized target variable name**
target_variable = 'wellness_score'

print(f"\nScatter plots of numeric variables vs {target_variable}:")
for col in numeric_cols:
    if col != target_variable:
        plt.figure(figsize=(6, 4))
        sns.scatterplot(data=df_merged, x=col, y=target_variable)
        plt.title(f'{target_variable} vs {col}')
        plt.show()

print(f"\nBoxplots of categorical variables vs {target_variable}:")
for col in categorical_cols:
    plt.figure(figsize=(8, 4))
    sns.boxplot(data=df_merged, x=col, y=target_variable)
    plt.xticks(rotation=45)
    plt.title(f'{target_variable} vs {col}')
    plt.show()

# Handling Skewness

from scipy.stats import skew

# Calculate skewness
skewness = df_merged[numeric_cols].apply(lambda x: skew(x.dropna()))
skewness = skewness.sort_values(ascending=False)

print("\nSkewness of numeric features:")
print(skewness)

# Identify highly skewed features
skewed_features = skewness[abs(skewness) > 0.5].index

# Apply log transformation
for col in skewed_features:
    # Since log transformation cannot be applied to negative values, shift the data if necessary
    if (df_merged[col] <= 0).any():
        df_merged[col] = df_merged[col] - df_merged[col].min() + 1
    df_merged[col] = np.log1p(df_merged[col])

# Recalculate skewness after transformation
new_skewness = df_merged[skewed_features].apply(lambda x: skew(x.dropna()))
print("\nSkewness after log transformation:")
print(new_skewness)

# Correlation with Target Variable

# Compute correlations with target variable
target_corr = df_merged[numeric_cols].corr()[target_variable].sort_values(ascending=False)

print(f"\nCorrelation with {target_variable}:")
print(target_corr)

# Plot correlations
plt.figure(figsize=(6, 8))
target_corr.drop(target_variable).plot(kind='barh')
plt.title(f'Correlation with {target_variable}')
plt.xlabel('Correlation coefficient')
plt.ylabel('Features')
plt.show()

# Save Cleaned Data for Modeling

# Save the cleaned and preprocessed data to a new CSV file
df_merged.to_csv('cleaned_data.csv', index=False)
print("\nCleaned data saved to 'cleaned_data.csv'.")
# Out:
# First few rows of the merged dataset:
#   public_id assessment_completed_date month_being_assessed  goal_no_new_debt  \
# 0       123                2022-08-03           2022-07-01              True
# 1       123                2022-08-03           2022-07-01              True
# 2       123                2022-08-03           2022-07-01              True
# 3       123                2022-08-03           2022-07-01              True
# 4       123                2022-08-03           2022-07-01              True
#
#    goal_paid_bills_on_time  goal_paid_parachute_on_time reason  \
# 0                     True                          1.0    NaN
# 1                     True                          1.0    NaN
# 2                     True                          1.0    NaN
# 3                     True                          1.0    NaN
# 4                     True                          1.0    NaN
#
#    under_utilization  user_id plan_date1  ...  qualified / verified\nincome  \
# 0              False     2241        NaT  ...                      116000.0
# 1              False     2241        NaT  ...                      116000.0
# 2              False     2241        NaT  ...                      116000.0
# 3              False     2241        NaT  ...                      116000.0
# 4              False     2241        NaT  ...                      116000.0
#
#    aptitude for change score  financial literacy score  self assessments  \
# 0                        NaN                       NaN               NaN
# 1                        NaN                       NaN               NaN
# 2                        NaN                       NaN               NaN
# 3                        NaN                       NaN               NaN
# 4                        NaN                       NaN               NaN
#
#    quiz count mood count inspiration count total activies  \
# 0         NaN        NaN               NaN            NaN
# 1         NaN        NaN               NaN            NaN
# 2         NaN        NaN               NaN            NaN
# 3         NaN        NaN               NaN            NaN
# 4         NaN        NaN               NaN            NaN
#
#    average total activities per month  average activities per day
# 0                                 NaN                         NaN
# 1                                 NaN                         NaN
# 2                                 NaN                         NaN
# 3                                 NaN                         NaN
# 4                                 NaN                         NaN
#
# [5 rows x 64 columns]
# DataFrame Information:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27997 entries, 0 to 28133
# Data columns (total 64 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   public_id                           27997 non-null  object
#  1   assessment_completed_date           27997 non-null  datetime64[ns]
#  2   month_being_assessed                27997 non-null  datetime64[ns]
#  3   goal_no_new_debt                    27997 non-null  bool
#  4   goal_paid_bills_on_time             27997 non-null  bool
#  5   goal_paid_parachute_on_time         27957 non-null  float64
#  6   reason                              1892 non-null   object
#  7   under_utilization                   27997 non-null  bool
#  8   user_id                             27997 non-null  int64
#  9   plan_date1                          4527 non-null   datetime64[ns]
#  10  plan_apply_savings_to_cc            4527 non-null   float64
#  11  plan_auto_withdrawal                4527 non-null   float64
#  12  plan_chat_before_new_debt           4527 non-null   float64
#  13  plan_chat_for_debt_reduction        4527 non-null   float64
#  14  plan_contact_biller                 4527 non-null   float64
#  15  description1                        78 non-null     object
#  16  description2                        211 non-null    object
#  17  description3                        93 non-null     object
#  18  plan_no_new_debt_upcoming_month     4527 non-null   float64
#  19  plan_pay_more_on_cc                 4527 non-null   float64
#  20  plan_pay_of_cc                      4527 non-null   float64
#  21  plan_spend_less                     4527 non-null   float64
#  22  count_apply_savings_to_cc           27997 non-null  int64
#  23  count_auto_withdrawal               27997 non-null  int64
#  24  count_chat_before_new_debt          27997 non-null  int64
#  25  count_chat_for_debt_reduction       27997 non-null  int64
#  26  count_contact_biller                27997 non-null  int64
#  27  count_no_new_debt_upcoming_month    27997 non-null  int64
#  28  count_pay_more_on_cc                27997 non-null  int64
#  29  count_pay_of_cc                     27997 non-null  int64
#  30  count_spend_less                    27997 non-null  int64
#  31  count_custom1                       27997 non-null  int64
#  32  count_custom2                       27997 non-null  int64
#  33  count_custom3                       27997 non-null  int64
#  34  loanid                              27978 non-null  object
#  35  month                               27978 non-null  object
#  36  quiz_answer_count                   27978 non-null  float64
#  37  mood_answer_count                   27978 non-null  float64
#  38  inspiration_answer_count            27978 non-null  float64
#  39  self_assessment_count               27978 non-null  float64
#  40  activities_count                    27978 non-null  float64
#  41  wellness_score                      25593 non-null  float64
#  42  disbursement date                   27853 non-null  datetime64[ns]
#  43  loan status                         27853 non-null  object
#  44  loan amount                         27853 non-null  float64
#  45  outstanding balance                 27853 non-null  float64
#  46  outstanding principal               27853 non-null  float64
#  47  interest rate                       27853 non-null  float64
#  48  loan term (months)                  27853 non-null  float64
#  49  date of birth                       27853 non-null  datetime64[ns]
#  50  gender                              27853 non-null  object
#  51  province                            27853 non-null  object
#  52  residential status                  27853 non-null  object
#  53  stated income on application        27853 non-null  float64
#  54  qualified / verified
# income         27853 non-null  float64
#  55  aptitude for change score           27508 non-null  float64
#  56  financial literacy score            27508 non-null  float64
#  57  self assessments                    23964 non-null  float64
#  58  quiz count                          23964 non-null  float64
#  59  mood count                          23964 non-null  float64
#  60  inspiration count                   23964 non-null  float64
#  61  total activies                      23964 non-null  float64
#  62  average total activities per month  23964 non-null  float64
#  63  average activities per day          23964 non-null  float64
# dtypes: bool(3), datetime64[ns](5), float64(32), int64(13), object(11)
# memory usage: 13.3+ MB
#
# Summary Statistics for Numeric Variables:
#            assessment_completed_date           month_being_assessed  \
# count                          27997                          27997
# mean   2023-12-29 04:53:16.628210176  2023-11-26 13:32:48.768082432
# min              2022-08-01 00:00:00            2022-07-01 00:00:00
# 25%              2023-08-07 00:00:00            2023-07-01 00:00:00
# 50%              2024-02-01 00:00:00            2024-01-01 00:00:00
# 75%              2024-06-02 00:00:00            2024-05-01 00:00:00
# max              2024-10-07 00:00:00            2024-09-01 00:00:00
# std                              NaN                            NaN
#
#        goal_paid_parachute_on_time       user_id  \
# count                 27957.000000  2.799700e+04
# mean                      0.867368  3.291814e+06
# min                       0.000000  1.519000e+03
# 25%                       1.000000  6.785200e+04
# 50%                       1.000000  7.817390e+05
# 75%                       1.000000  2.072132e+06
# max                       1.000000  1.979250e+07
# std                       0.339183  5.304706e+06
#
#                           plan_date1  plan_apply_savings_to_cc  \
# count                           4527               4527.000000
# mean   2024-05-04 06:54:28.389661952                  0.405567
# min              2024-02-01 00:00:00                  0.000000
# 25%              2024-03-04 00:00:00                  0.000000
# 50%              2024-05-02 00:00:00                  0.000000
# 75%              2024-07-01 00:00:00                  1.000000
# max              2024-08-09 00:00:00                  1.000000
# std                              NaN                  0.491056
#
#        plan_auto_withdrawal  plan_chat_before_new_debt  \
# count           4527.000000                4527.000000
# mean               0.011487                   0.044179
# min                0.000000                   0.000000
# 25%                0.000000                   0.000000
# 50%                0.000000                   0.000000
# 75%                0.000000                   0.000000
# max                1.000000                   1.000000
# std                0.106570                   0.205516
#
#        plan_chat_for_debt_reduction  plan_contact_biller  ...  \
# count                   4527.000000          4527.000000  ...
# mean                       0.015905             0.039982  ...
# min                        0.000000             0.000000  ...
# 25%                        0.000000             0.000000  ...
# 50%                        0.000000             0.000000  ...
# 75%                        0.000000             0.000000  ...
# max                        1.000000             1.000000  ...
# std                        0.125120             0.195939  ...
#
#        qualified / verified\nincome  aptitude for change score  \
# count                  27853.000000               27508.000000
# mean                   77418.909633                   3.559828
# min                    32000.000000                   0.000000
# 25%                    54000.000000                   3.000000
# 50%                    68000.000000                   3.670000
# 75%                    90000.000000                   4.170000
# max                   605300.000000                   5.000000
# std                    59114.615524                   1.032383
#
#        financial literacy score  self assessments    quiz count    mood count  \
# count              27508.000000      23964.000000  23964.000000  23964.000000
# mean                   2.217937         17.113671    133.645593     23.141587
# min                    0.000000          1.000000      0.000000      0.000000
# 25%                    0.000000         13.000000    101.000000      1.000000
# 50%                    3.000000         17.000000    136.000000      7.000000
# 75%                    4.000000         23.000000    178.000000     32.000000
# max                    5.000000         26.000000    211.000000    120.000000
# std                    1.809928          5.927881     54.234112     31.193823
#
#        inspiration count  total activies  average total activities per month  \
# count       23964.000000    23964.000000                        23964.000000
# mean           13.477925      187.378776                           10.025526
# min             0.000000        1.000000                            0.061200
# 25%             0.000000      122.000000                            8.775500
# 50%             4.000000      162.000000                            9.430300
# 75%            17.000000      265.000000                           11.134000
# max            66.000000      404.000000                           20.886100
# std            17.912213       95.946505                            3.270459
#
#        average activities per day
# count                23964.000000
# mean                     0.334185
# min                      0.002000
# 25%                      0.292500
# 50%                      0.314300
# 75%                      0.371100
# max                      0.696200
# std                      0.109013
#
# [8 rows x 50 columns]
# Summary Statistics for Categorical Variables:
#        public_id                                             reason  \
# count      27997                                               1892
# unique       192                                                111
# top         1280  I did pay my loan on time every month, how it ...
# freq         702                                                 27
#
#                                              description1  \
# count                                                  78
# unique                                                  7
# top     This month was a one off as I usually pay my b...
# freq                                                   26
#
#                                              description2 description3 loanid  \
# count                                                 211           93  27978
# unique                                                 15            8    183
# top     My employer owes me OT pay + retro pay. Those ...      lkjhgfd   1280
# freq                                                   26           23    702
#
#           month loan status gender province residential status
# count     27978       27853  27853    27853              27853
# unique       28           4      2        9                  4
# top     2024-03      Active   MALE       ON             RENTER
# freq       1570       23347  16267    20057              18685
# Missing Values in the Dataset:
#                                  Total Missing  Percent Missing
# description1                             27919        99.721399
# description3                             27904        99.667822
# description2                             27786        99.246348
# reason                                   26105        93.242133
# plan_spend_less                          23470        83.830410
# plan_pay_of_cc                           23470        83.830410
# plan_pay_more_on_cc                      23470        83.830410
# plan_no_new_debt_upcoming_month          23470        83.830410
# plan_date1                               23470        83.830410
# plan_apply_savings_to_cc                 23470        83.830410
# plan_auto_withdrawal                     23470        83.830410
# plan_chat_before_new_debt                23470        83.830410
# plan_chat_for_debt_reduction             23470        83.830410
# plan_contact_biller                      23470        83.830410
# average activities per day                4033        14.405115
# self assessments                          4033        14.405115
# quiz count                                4033        14.405115
# mood count                                4033        14.405115
# inspiration count                         4033        14.405115
# total activies                            4033        14.405115
# Dropped columns due to high missing rate (> 50%):
# ['description1', 'description3', 'description2', 'reason', 'plan_spend_less', 'plan_pay_of_cc', 'plan_pay_more_on_cc', 'plan_no_new_debt_upcoming_month', 'plan_date1', 'plan_apply_savings_to_cc', 'plan_auto_withdrawal', 'plan_chat_before_new_debt', 'plan_chat_for_debt_reduction', 'plan_contact_biller']
#
# Plotting histograms for numeric variables...
# Plotting bar charts for categorical variables...
# Correlation Matrix of Numeric Variables:
# All subset columns are present in df_merged.
#
# Plotting pairplot for selected variables...
# Scatter plots of numeric variables vs wellness_score:
# Boxplots of categorical variables vs wellness_score:
# Skewness of numeric features:
# self_assessment_count                 15.336928
# count_auto_withdrawal                  9.340812
# count_chat_for_debt_reduction          8.644724
# qualified / verified\nincome           7.363613
# count_custom1                          7.212561
# stated income on application           6.713908
# count_custom3                          6.643791
# count_spend_less                       6.617518
# count_contact_biller                   5.068328
# count_pay_of_cc                        4.513602
# count_custom2                          3.700998
# inspiration_answer_count               3.667283
# count_no_new_debt_upcoming_month       3.615027
# mood_answer_count                      3.249493
# count_chat_before_new_debt             3.153050
# count_apply_savings_to_cc              1.694120
# activities_count                       1.685322
# user_id                                1.578383
# mood count                             1.522672
# inspiration count                      1.486037
# count_pay_more_on_cc                   1.004555
# total activies                         0.462372
# loan amount                            0.170248
# wellness_score                         0.086240
# average total activities per month    -0.027561
# average activities per day            -0.027780
# self assessments                      -0.086656
# financial literacy score              -0.096032
# outstanding balance                   -0.201926
# outstanding principal                 -0.271325
# quiz count                            -0.280556
# quiz_answer_count                     -0.481819
# interest rate                         -0.950012
# loan term (months)                    -1.242641
# aptitude for change score             -1.301002
# goal_paid_parachute_on_time           -2.166231
# dtype: float64
#
# Skewness after log transformation:
# self_assessment_count               1.266365
# count_auto_withdrawal               8.875087
# count_chat_for_debt_reduction       7.919072
# qualified / verified\nincome        1.540137
# count_custom1                       5.992433
# stated income on application       -0.039404
# count_custom3                       5.441575
# count_spend_less                    5.446753
# count_contact_biller                4.736356
# count_pay_of_cc                     4.009421
# count_custom2                       3.245296
# inspiration_answer_count            2.050336
# count_no_new_debt_upcoming_month    2.519215
# mood_answer_count                   1.401447
# count_chat_before_new_debt          2.916723
# count_apply_savings_to_cc           1.195860
# activities_count                   -1.353040
# user_id                            -0.537865
# mood count                          0.222696
# inspiration count                   0.276138
# count_pay_more_on_cc                0.598614
# interest rate                      -0.964411
# loan term (months)                 -1.561632
# aptitude for change score          -2.447715
# goal_paid_parachute_on_time        -2.166231
# dtype: float64
#
# Correlation with wellness_score:
# wellness_score                        1.000000
# aptitude for change score             0.199798
# count_custom2                         0.150888
# stated income on application          0.149854
# qualified / verified\nincome          0.117027
# loan term (months)                    0.105925
# loan amount                           0.091511
# self_assessment_count                 0.027699
# count_apply_savings_to_cc             0.008202
# financial literacy score              0.006202
# goal_paid_parachute_on_time           0.002021
# count_pay_more_on_cc                  0.001589
# inspiration_answer_count             -0.003191
# user_id                              -0.009824
# self assessments                     -0.016364
# count_chat_before_new_debt           -0.023260
# outstanding principal                -0.032280
# mood_answer_count                    -0.034273
# quiz count                           -0.043867
# total activies                       -0.048387
# quiz_answer_count                    -0.052021
# outstanding balance                  -0.061115
# activities_count                     -0.066239
# count_pay_of_cc                      -0.067208
# interest rate                        -0.068926
# count_custom1                        -0.078026
# inspiration count                    -0.093170
# count_custom3                        -0.094605
# count_spend_less                     -0.103461
# mood count                           -0.120719
# average total activities per month   -0.128824
# average activities per day           -0.128838
# count_chat_for_debt_reduction        -0.167005
# count_auto_withdrawal                -0.195146
# count_no_new_debt_upcoming_month     -0.228256
# count_contact_biller                 -0.228799
# Name: wellness_score, dtype: float64
# Cleaned data saved to 'cleaned_data.csv'.
